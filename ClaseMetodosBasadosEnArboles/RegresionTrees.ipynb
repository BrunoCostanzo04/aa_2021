# %% [markdown]
# # Regresion Trees

# %% [markdown]
# Usaremos el dataset de Boston Housing para nuestro ejemplo de regresión. Este es un dataset muy popular que contiene información sobre casas en los suburbios de Boston. Hay 506 muestras y 14 atributos.

# %%
import pandas as pd
from sklearn import datasets
from sklearn.tree import DecisionTreeRegressor
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeRegressor
from sklearn.tree import plot_tree
import seaborn as sns

# %%
boston = pd.read_csv("https://raw.githubusercontent.com/rdambrosioz/aa_2021/main/ClaseMetodosBasadosEnArboles/HousingData.csv")
boston.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         B  LSTAT  MEDV
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90    NaN  36.2

# %%
boston.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  486.000000  486.000000  486.000000  486.000000  506.000000  506.000000
# mean     3.611874   11.211934   11.083992    0.069959    0.554695    6.284634
# std      8.720192   23.388876    6.835896    0.255340    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.081900    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.253715    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.560263   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  486.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.518519    3.795043    9.549407  408.237154   18.455534  356.674032
# std     27.999513    2.105710    8.707259  168.537116    2.164946   91.294864
# min      2.900000    1.129600    1.000000  187.000000   12.600000    0.320000
# 25%     45.175000    2.100175    4.000000  279.000000   17.400000  375.377500
# 50%     76.800000    3.207450    5.000000  330.000000   19.050000  391.440000
# 75%     93.975000    5.188425   24.000000  666.000000   20.200000  396.225000
# max    100.000000   12.126500   24.000000  711.000000   22.000000  396.900000
#
#             LSTAT        MEDV
# count  486.000000  506.000000
# mean    12.715432   22.532806
# std      7.155871    9.197104
# min      1.730000    5.000000
# 25%      7.125000   17.025000
# 50%     11.430000   21.200000
# 75%     16.955000   25.000000
# max     37.970000   50.000000

# %%
boston.isnull().sum()
# Out:
# CRIM       20
# ZN         20
# INDUS      20
# CHAS       20
# NOX         0
# RM          0
# AGE        20
# DIS         0
# RAD         0
# TAX         0
# PTRATIO     0
# B           0
# LSTAT      20
# MEDV        0
# dtype: int64

# %%
boston.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CRIM     486 non-null    float64
#  1   ZN       486 non-null    float64
#  2   INDUS    486 non-null    float64
#  3   CHAS     486 non-null    float64
#  4   NOX      506 non-null    float64
#  5   RM       506 non-null    float64
#  6   AGE      486 non-null    float64
#  7   DIS      506 non-null    float64
#  8   RAD      506 non-null    int64
#  9   TAX      506 non-null    int64
#  10  PTRATIO  506 non-null    float64
#  11  B        506 non-null    float64
#  12  LSTAT    486 non-null    float64
#  13  MEDV     506 non-null    float64
# dtypes: float64(12), int64(2)
# memory usage: 55.5 KB

# %%
# La variable CHAS no es categorica => la convertimos 

boston['CHAS']=boston['CHAS'].astype(object)
boston.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CRIM     486 non-null    float64
#  1   ZN       486 non-null    float64
#  2   INDUS    486 non-null    float64
#  3   CHAS     486 non-null    object
#  4   NOX      506 non-null    float64
#  5   RM       506 non-null    float64
#  6   AGE      486 non-null    float64
#  7   DIS      506 non-null    float64
#  8   RAD      506 non-null    int64
#  9   TAX      506 non-null    int64
#  10  PTRATIO  506 non-null    float64
#  11  B        506 non-null    float64
#  12  LSTAT    486 non-null    float64
#  13  MEDV     506 non-null    float64
# dtypes: float64(11), int64(2), object(1)
# memory usage: 55.5+ KB

# %%
# Tratamos los valores que nos faltan

# Reemplazamos los valores faltantes por el promedio
boston[['CRIM','ZN','INDUS','AGE','LSTAT']] = boston[['CRIM','ZN','INDUS','AGE','LSTAT']].fillna((boston[['CRIM','ZN','INDUS','AGE','LSTAT']].mean()))

# Utilizamos el metodo 'bfill'
boston['CHAS']=boston['CHAS'].fillna(method='bfill')

# %%
plt.figure(figsize=(20,20))
boston.hist()
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10,10))
sns.heatmap(boston.corr(method='pearson'), cbar=True, cmap='RdYlBu')
plt.title('Correlation Matrix - Pearson')
plt.show()

# %%
# Spliteamos en los vectores X e Y

X = boston.iloc[:,0:-1]
Y = boston.iloc[:,-1]

# %%
X.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         B      LSTAT
# 0  396.90   4.980000
# 1  396.90   9.140000
# 2  392.83   4.030000
# 3  394.63   2.940000
# 4  396.90  12.715432

# %%
Y.head()
# Out:
# 0    24.0
# 1    21.6
# 2    34.7
# 3    33.4
# 4    36.2
# Name: MEDV, dtype: float64

# %%
X_train,X_test,Y_train,Y_test = train_test_split(X, Y, test_size = 0.3, random_state = 0)

# %%
regressor = DecisionTreeRegressor(max_depth = 6)
DT_reg = regressor.fit(X_train, Y_train)

# %%
DT_reg
# Out:
# DecisionTreeRegressor(max_depth=6)

# %%
print (DT_reg.score(X_train,Y_train))
print (DT_reg.score(X_test,Y_test))
# Out:
# 0.9546961106932489
# 0.6861702511935571

# %%
Y_pred = DT_reg.predict(X_test)
Y_pred
# Out:
# array([23.08245614, 23.08245614, 20.51358025, 13.21578947, 20.51358025,
#        23.08245614, 20.51358025, 23.08245614, 20.51358025, 20.51358025,
#         7.1       , 17.9       , 13.21578947, 10.7375    , 50.        ,
#        31.4       , 20.51358025, 34.36875   , 23.08245614, 23.08245614,
#        23.08245614, 20.51358025, 20.51358025, 23.08245614, 20.51358025,
#        20.51358025, 20.51358025, 15.86666667, 42.4       , 19.80454545,
#        13.21578947, 13.21578947, 20.51358025, 20.51358025, 23.08245614,
#        17.30833333,  7.1       , 23.08245614, 17.30833333, 17.9       ,
#        23.08245614, 20.51358025, 23.08245614, 13.21578947, 23.08245614,
#        23.08245614, 15.66666667, 15.86666667, 14.14285714, 26.95555556,
#        14.14285714, 19.80454545, 20.51358025, 35.2       , 14.325     ,
#        19.80454545, 20.51358025, 20.51358025, 13.9       , 19.80454545,
#        23.08245614, 20.51358025, 31.4       , 24.8       , 13.21578947,
#        32.4       , 17.30833333, 19.80454545, 29.8       , 20.51358025,
#        20.51358025, 23.08245614, 23.08245614, 31.4       , 26.95555556,
#        10.7375    , 49.625     , 20.51358025, 23.08245614, 20.51358025,
#        26.95555556, 15.86666667, 20.51358025, 42.4       , 42.4       ,
#        23.08245614, 20.51358025, 17.30833333, 23.08245614, 17.30833333,
#        15.66666667, 10.7375    , 23.08245614, 31.4       , 23.08245614,
#        23.08245614, 12.21428571, 23.08245614, 17.30833333, 20.51358025,
#        23.08245614, 20.51358025, 31.4       , 20.51358025, 31.4       ,
#        20.51358025,  7.1       , 20.51358025, 23.08245614, 23.08245614,
#        31.4       , 17.9       , 19.80454545, 19.80454545, 19.80454545,
#        19.80454545, 10.7375    , 20.51358025, 10.7375    , 49.625     ,
#        26.95555556, 20.51358025, 15.66666667, 20.51358025, 20.51358025,
#        19.80454545, 34.36875   , 15.66666667, 23.08245614, 34.36875   ,
#        13.21578947,  7.1       , 15.2       , 14.325     , 10.4       ,
#        34.36875   , 20.51358025, 14.14285714, 26.95555556,  7.1       ,
#        12.21428571, 20.51358025, 31.4       , 23.08245614, 23.08245614,
#        14.325     , 34.36875   , 34.36875   ,  7.1       , 10.7375    ,
#        50.        , 23.08245614])

# %%
plt.figure(figsize=(25,10))
a = plot_tree(regressor, 
              feature_names=X.columns, 
              class_names=Y, 
              filled=True, 
              rounded=True, 
              fontsize=14)

# %% [markdown]
# Probamos cambiar el max_depth con 4,5,6,7 de los cuales max_depth = 6 nos dio la puntuación más alta en los datos de la prueba.
